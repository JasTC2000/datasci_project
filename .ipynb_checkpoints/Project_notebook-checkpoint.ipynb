# %%
# To import mcherry fluorescence data, first imported the pandas library into my jupyter notebook
import pandas as pd

# %%
pwd 
# here the data didn't load so I checked my working directory and moved my data to the correct folder
# Out:
# '/Users/jtc69/Documents/PhD/Taught modules/Data Science /Individual_Project'

# %%
df = pd.read_csv('mCherry.csv')
#this code loaded my csv file into pandas and created a dataframe object

# %%
df
#Here I checked that the object 'df' is my data set
# Out:
#     24-12-20 16-04-02 mCherry  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0   24-12-20 16-04-02 mCherry         NaN         NaN         NaN         NaN
# 1                        Well         0.0        10.0        20.0        30.0
# 2                         B02     15240.0     14671.0     14344.0     14161.0
# 3                         B03     14819.0     14824.0     14597.0     14636.0
# 4                         B04     15169.0     14571.0     14898.0     14420.0
# ..                        ...         ...         ...         ...         ...
# 57                        G07     14937.0     14623.0     14347.0     14242.0
# 58                        G08     14879.0     14354.0     14517.0     14162.0
# 59                        G09     14634.0     14383.0     14513.0     14126.0
# 60                        G10     14548.0     14425.0     14155.0     14050.0
# 61                        G11     14525.0     14309.0     13983.0     14114.0
#
# ...

# %%
#next the following codes explores my data 
df.head()
# Out:
#    24-12-20 16-04-02 mCherry  Unnamed: 1  Unnamed: 2  Unnamed: 3  Unnamed: 4  \
# 0  24-12-20 16-04-02 mCherry         NaN         NaN         NaN         NaN
# 1                       Well         0.0        10.0        20.0        30.0
# 2                        B02     15240.0     14671.0     14344.0     14161.0
# 3                        B03     14819.0     14824.0     14597.0     14636.0
# 4                        B04     15169.0     14571.0     14898.0     14420.0
#
#    Unnamed: 5  Unnamed: 6  Unnamed: 7  Unnamed: 8  Unnamed: 9  ...  \
# 0         NaN         NaN         NaN         NaN         NaN  ...
# 1        40.0        50.0        60.0        70.0        80.0  ...
# 2     14554.0     14245.0     14214.0     14120.0     14287.0  ...
# 3     14230.0     14344.0     14239.0     14366.0     14625.0  ...
# 4     14333.0     14257.0     14313.0     14561.0     14330.0  ...
#
#    Unnamed: 122  Unnamed: 123  Unnamed: 124  Unnamed: 125  Unnamed: 126  \
# ...

# %%
#I want to get rid of the top two rows as these are redundant.
